# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(12,12)
import seaborn as sns

# %%
df  = pd.read_excel(r"C:\Users\255046\Downloads\Inflow referral from 2017 Jan to 2023 September 14th.xlsx")

# %%
SME = df[df['Review_Type'] == 'SME on boarding']

# %%
sme = SME[['Min_of_Time_arrived','Review_Type']]
sme['Min_of_Time_arrived']=sme['Min_of_Time_arrived'].dt.date
sme['Min_of_Time_arrived']=pd.to_datetime(sme['Min_of_Time_arrived'])
sme = pd.DataFrame(sme.groupby('Min_of_Time_arrived')['Review_Type'].count()).reset_index()
sme = sme[sme['Min_of_Time_arrived'].dt.dayofweek < 5]
sme = sme[~sme['Min_of_Time_arrived'].dt.normalize().isin(date_list)]
sme.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1660 entries, 0 to 2180
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Min_of_Time_arrived  1660 non-null   datetime64[ns]
#  1   Review_Type          1660 non-null   int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 38.9 KB
# C:\Users\255046\AppData\Local\Temp\ipykernel_31256\1927488740.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sme['Min_of_Time_arrived']=sme['Min_of_Time_arrived'].dt.date
# C:\Users\255046\AppData\Local\Temp\ipykernel_31256\1927488740.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
sme.sample(20)
# Out:
#      Min_of_Time_arrived  Review_Type
# 830           2019-08-20           68
# 686           2019-03-08           80
# 2098          2023-06-06           82
# 1308          2021-02-02           93
# 650           2019-01-29           85
# 1075          2020-05-20           40
# 524           2018-09-05           59
# 922           2019-11-28           27
# 486           2018-07-23           41
# 1597          2021-12-23           59
# 136           2017-06-12          106
# 1407          2021-05-27           82
# 2041          2023-04-04           93
# 919           2019-11-25           51
# 718           2019-04-15           94
# 604           2018-12-04           78
# 706           2019-04-01           63
# 860           2019-09-23           78
# 95            2017-04-24           56
# 404           2018-04-18           58

# %%
holi_list = ['2017-01-01','2017-03-14','2017-03-17','2017-04-02','2017-04-05',
            '2017-05-03','2017-06-07','2017-06-20','2017-08-02','2017-10-25',
            '2017-12-25','2017-12-26','2017-12-29',
            '2018-01-01','2018-03-14','2018-03-17','2018-04-02','2018-04-05',
            '2018-05-03','2018-06-07','2018-06-20','2018-08-02','2018-10-25',
            '2018-12-25','2018-12-26','2018-12-29',
            '2019-01-01','2019-03-14','2019-03-17','2019-04-02','2019-04-05',
            '2019-05-03','2019-06-07','2019-06-20','2019-08-02','2019-10-25',
            '2019-12-25','2019-12-26','2019-12-29',
            '2020-01-01','2020-03-14','2020-03-17','2020-04-02','2020-04-05',
            '2020-05-03','2020-06-07','2020-06-20','2020-08-02','2020-10-25',
            '2020-12-25','2020-12-26','2020-12-29',
            '2021-01-01','2021-03-14','2021-03-17','2021-04-02','2021-04-05',
            '2021-05-03','2021-06-07','2021-06-20','2021-08-02','2021-10-25',
            '2021-12-25','2021-12-26','2021-12-29','2022-01-01','2022-01-03','2022-03-17','2022-03-18','2022-03-27','2022-04-15','2022-04-18',
            '2022-05-02','2022-06-06','2022-06-19','2022-08-01','2022-10-31','2022-12-25',
            '2022-12-26','2022-12-27','2022-12-28',
            '2023-01-02','2023-02-06','2023-03-17','2023-04-07','2023-04-10',
            '2023-05-01','2023-06-05','2023-08-07','2023-10-30','2023-11-13','2023-12-25','2023-12-26',
            '2023-12-27','2023-12-28','2023-12-29','2024-01-01','2024-02-05']

date_list = pd.to_datetime(holi_list)

# %%
df1=pd.read_excel(r'C:\Users\255046\Downloads\Referral data September 2023 to February 22nd 2024.xlsx',sheet_name='SME')

# %%
SME1 =df1.loc[df1['Organization'].isin(['Small Business &amp; Agriculture','Branch','Direct'])]

# %%
sme1 = SME1[['Min_of_Time_arrived','Review_Type']]
sme1['Min_of_Time_arrived']=sme1['Min_of_Time_arrived'].dt.date
sme1['Min_of_Time_arrived']=pd.to_datetime(sme1['Min_of_Time_arrived'])
sme1 = pd.DataFrame(sme1.groupby('Min_of_Time_arrived')['Review_Type'].count()).reset_index()
sme1 = sme1[sme1['Min_of_Time_arrived'].dt.dayofweek < 5]
sme1 = sme1[~sme1['Min_of_Time_arrived'].dt.normalize().isin(date_list)]
sme1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 116 entries, 0 to 156
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Min_of_Time_arrived  116 non-null    datetime64[ns]
#  1   Review_Type          116 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.7 KB
# C:\Users\255046\AppData\Local\Temp\ipykernel_31256\2360341855.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sme1['Min_of_Time_arrived']=sme1['Min_of_Time_arrived'].dt.date
# C:\Users\255046\AppData\Local\Temp\ipykernel_31256\2360341855.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
sme1.head(20)
# Out:
#    Min_of_Time_arrived  Review_Type
# 0           2023-09-01           57
# 3           2023-09-04           65
# 4           2023-09-05           95
# 5           2023-09-06           84
# 6           2023-09-07           87
# 7           2023-09-08           71
# 10          2023-09-11           61
# 11          2023-09-12           70
# 12          2023-09-13           93
# 13          2023-09-14           77
# 14          2023-09-15           76
# 16          2023-09-18           72
# 17          2023-09-19          134
# 18          2023-09-20           94
# 19          2023-09-21           83
# 20          2023-09-22           50
# 23          2023-09-25          112
# 24          2023-09-26           93
# 25          2023-09-27           86
# 26          2023-09-28           95

# %%
final=pd.concat([sme,sme1],ignore_index=True)

# %%
final.tail()
# Out:
#      Min_of_Time_arrived  Review_Type
# 1771          2024-02-16          111
# 1772          2024-02-19          136
# 1773          2024-02-20          122
# 1774          2024-02-21          102
# 1775          2024-02-22          144

# %%
final = final.set_index('Min_of_Time_arrived')
final.plot(figsize=(15,10))
plt.xlabel('Min_of_Time_arrived')
plt.ylabel('Count')
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
# temp = df2[['Refferal_Count']]
decom = seasonal_decompose(final['Review_Type'], model='additive', period=24)
decom.plot()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
x = final.Review_Type.values
result=adfuller(x)
print('ADF Statistic: %f'%result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
   print('\t%s: %.3f' % (key, value))
if result[0] < result[4]["5%"]:
   print ("Reject Ho - Time Series is Stationary")
else:
   print ("Failed to Reject Ho - Time Series is Non-Stationary")
# Out:
# ADF Statistic: -2.958748
# p-value: 0.038931
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
# Reject Ho - Time Series is Stationary

# %%
print(len(final)*0.9)
train_df = final[0:1600]
test_df = final[1600::]
print(len(final))
print(len(train_df))
print(len(test_df))
# Out:
# 1598.4
# 1776
# 1600
# 176

# %%
from prophet.diagnostics import cross_validation
from prophet.diagnostics import performance_metrics
from tqdm import tqdm
from prophet import Prophet

# %%
#  param_grid = {  
# 'changepoint_prior_scale': [0.001, 0.01, 0.1, 0.5],
# 'seasonality_prior_scale': [0.01, 0.1, 1.0, 10.0],
# 'seasonality_mode': ['multiplicative', 'additive'],
# 'growth': ['linear', 'logistic'],
# 'yearly_seasonality':[5,10,20,40],
# 'weekly_seasonality':[5,10,20,40],
# 'daily_seasonality':[5,10,20,40],
# }

# %%
# prophet_model = Prophet(growth = 'linear',holidays_prior_scale=200, daily_seasonality=5,changepoint_range=0.9,changepoint_prior_scale=0.01,yearly_seasonality=30,seasonality_prior_scale=0.1, weekly_seasonality=10,seasonality_mode='additive')
# prophet_model.add_seasonality(name='weekly_off_season', period=6, fourier_order=8,prior_scale=80)
# prophet_model.add_seasonality(name='monthly', period=30.5, fourier_order=20,prior_scale=30)
# prophet_model.add_seasonality(name='yearly', period=365.25, fourier_order=24,prior_scale=60)
# prophet_model.add_seasonality(name='daily',period=1,fourier_order=80,prior_scale=40) #15%,-2

# %%
prophet_model = Prophet(growth = 'linear',holidays_prior_scale=150, daily_seasonality=5,changepoint_range=0.9,changepoint_prior_scale=0.01,yearly_seasonality=30,seasonality_prior_scale=0.1, weekly_seasonality=10,seasonality_mode='additive')
prophet_model.add_seasonality(name='weekly_off_season', period=5, fourier_order=8,prior_scale=80)
prophet_model.add_seasonality(name='monthly', period=30.5, fourier_order=20,prior_scale=30)
prophet_model.add_seasonality(name='yearly', period=365.25, fourier_order=24,prior_scale=60)
prophet_model.add_seasonality(name='daily',period=1,fourier_order=80,prior_scale=40)

# %%
pro_train = train_df.copy()
pro_test = test_df.copy()

# %%
pro_train = pro_train.reset_index()
pro_test = pro_test.reset_index()

# %%
pro_train = pro_train.rename(columns={'Min_of_Time_arrived': 'ds', 'Review_Type': 'y'})
pro_test = pro_test.rename(columns={'Min_of_Time_arrived': 'ds', 'Review_Type': 'y'})

# %%
prophet_model.fit(pro_train)
# Out:
# 15:38:14 - cmdstanpy - INFO - Chain [1] start processing
# 15:38:15 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = pd.DataFrame()
future['ds'] = pro_test['ds']

# %%
prophet_forecast = prophet_model.predict(future)

# %%
mean_absolute_percentage_error(prophet_forecast['yhat']-10,pro_test['y'])
# Out:
# 0.16598809871815312

# %%
from sklearn.metrics import *

# %%
pro_train = final.copy()

# %%
pro_train = pro_train.reset_index()

# %%
pro_train = pro_train.rename(columns={'Min_of_Time_arrived': 'ds', 'Review_Type': 'y'})

# %%
prophet_model.fit(pro_train)
# Out:
# 14:18:15 - cmdstanpy - INFO - Chain [1] start processing
# 14:18:16 - cmdstanpy - INFO - Chain [1] done processing

# %%
forecast_days = pd.bdate_range(start='2024-01-01',end='2024-12-31',freq='D')

# %%
holiday_list=['2024-04-01','2024-05-06','2024-06-03','2024-08-05','2024-10-28','2024-10-31','2024-12-25',
              '2024-12-26','2024-12-27']

# %%
forecast_days = forecast_days[~forecast_days.isin(holiday_list)]

# %%
forecast_days
# Out:
# DatetimeIndex(['2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05',
#                '2024-01-06', '2024-01-07', '2024-01-08', '2024-01-09',
#                '2024-01-10', '2024-01-11',
#                ...
#                '2024-12-19', '2024-12-20', '2024-12-21', '2024-12-22',
#                '2024-12-23', '2024-12-24', '2024-12-28', '2024-12-29',
#                '2024-12-30', '2024-12-31'],
#               dtype='datetime64[ns]', length=355, freq=None)

# %%
future = pd.DataFrame()
future['ds'] = forecast_days

# %%
prophet_forecast = prophet_model.predict(future)

# %%
prophet_forecast['yhat']=prophet_forecast['yhat']-10

# %%
prophet_forecast[['ds','yhat']].to_excel('SME_daily.xlsx',index=False)

# %%
prophet_forecast
# Out:
#             ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   2023-06-08   98.129510   70.806765  115.304696    98.129510    98.129510
# 1   2023-06-09   98.162368   75.226333  120.834389    98.162368    98.162368
# 2   2023-06-12   98.260943   83.811252  128.581444    98.260943    98.260943
# 3   2023-06-13   98.293801   92.096954  133.991349    98.293801    98.293801
# 4   2023-06-14   98.326659   94.080726  139.171750    98.326659    98.326659
# ..         ...         ...         ...         ...          ...          ...
# 171 2024-02-16  106.442605  104.135080  147.352509   105.965382   106.905417
# 172 2024-02-19  106.541180  105.132931  148.051321   106.058731   107.008037
# 173 2024-02-20  106.574038  106.324933  149.214138   106.086739   107.045240
# 174 2024-02-21  106.606896  104.846496  148.527333   106.114361   107.081856
# 175 2024-02-22  106.639754  108.856961  153.377922   106.142159   107.117231
#
# ...

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from itertools import product
from tqdm import tqdm_notebook

# %%
def sarima(parameter_list, d,D,s,exog):
    result =[]
    for param in tqdm_notebook(parameter_list):
        try:
            model = SARIMAX(exog, order=(param[0],d,param[1]),
                          seasonal_order=(param[2],D,param[3],s)).fit()
        except:
            continue
        aic = model.aic
        result.append([param, aic])
    result_df = pd.DataFrame(result)
    result_df.columns = ['(p,q)x(P,Q)','AIC']
    result_df = result_df.sort_values(by = 'AIC', ascending = True).reset_index(drop = True)
    return result_df

# %%
p = range(0,4,1)
d = 1
q = range(0,4,1)
D = 1
P = range(0,4,1)
Q = range(0,4,1)
s = 7
parameters = product(p,q,P,Q)
parameter_list = list(parameters)
print(len(parameter_list))
# Out:
# 256

# %%
result_df=sarima(parameter_list,1,1,7,train_df["Review_Type"])
# Out:
# C:\Users\255046\AppData\Local\Temp\ipykernel_7084\1541314336.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for param in tqdm_notebook(parameter_list):
#   0%|          | 0/256 [00:00<?, ?it/s]
# C:\Users\255046\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\255046\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %%
result_df
# Out:
#       (p,q)x(P,Q)           AIC
# 0    (3, 3, 3, 3)  13664.170487
# 1    (3, 3, 1, 3)  13665.952708
# 2    (3, 3, 2, 2)  13667.033212
# 3    (3, 2, 1, 1)  13667.824634
# 4    (3, 2, 0, 2)  13668.127995
# ..            ...           ...
# 251  (0, 0, 1, 0)  14923.695556
# 252  (3, 0, 0, 0)  14961.290943
# 253  (2, 0, 0, 0)  15035.244481
# 254  (1, 0, 0, 0)  15142.052013
# 255  (0, 0, 0, 0)  15400.684903
#
# [256 rows x 2 columns]

# %%
#(1,1,5),seasonal_order=(1,1,2,12) - 21%mape

# %%
final_model1=SARIMAX(train_df['Review_Type'],order=(3,0,3),seasonal_order=(3,0,5,12)).fit()
# Out:
# C:\Users\255046\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\255046\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\255046\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ...

# %%
df_forecast1=pd.DataFrame()
df_forecast1['forecast'] =final_model1.predict(start=1601, end=1776)
#df_forecast['forecast'] =sarimax_model.predict(start=1276, end=1595)+10
df_forecast1.index=test_df.index
df_forecast1['actual'] =test_df['Review_Type']
from sklearn.metrics import *
sarimax_model_mape = mean_absolute_percentage_error (df_forecast1['actual'], df_forecast1['forecast'])
print(sarimax_model_mape)
df_forecast1.plot()
# Out:
# 0.18344128261317116
# C:\Users\255046\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# <Axes: xlabel='Min_of_Time_arrived'>
