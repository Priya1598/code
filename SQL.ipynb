# %%
import pandas as pd
import numpy as np

# %%
xls = pd.ExcelFile(r'C:\Users\180100\OneDrive - NTT DATA North America\Automations_\SQL upload\DEI Training Data.xlsx')
xls

# %%
df1 = pd.read_excel (xls,'TBL_Bronze')
#df2 = pd.read_excel (xls,'TBL_Silver')
#df3 = pd.read_excel (xls,'TBL_Gold')

# %%
df1
# Out:
#        Portal Id          Employee Name Is Hlm Employee Type  Grade  \
# 0             33       Anthony Robinson    Yes      Employee   11.0
# 1             40            Louis Calla    Yes      Employee   14.0
# 2            134         Paula Passmore    Yes      Employee   13.0
# 3            163              Tom Keefe    Yes      Employee   12.0
# 4            360        Suzanne Wachler     No      Employee    9.0
# ...          ...                    ...    ...           ...    ...
# 21145     337336        MALINI KRISHNAN     No      Employee    3.0
# 21146     337343          Karan Shankar     No      Employee    3.0
# 21147     337344        LOKESWAR MURALI     No      Employee    3.0
# 21148     337400  Sandesh Shamrao Surve     No      Employee   10.0
# 21149     337512            Suresh Doki     No      Employee   10.0
#
#         Work Country  Company Code Enrolled Date  Elapsed Days  \
# 0      United States        1001.0     8/30/2021          1150
# ...

# %%
import urllib

from sqlalchemy import create_engine

import pyodbc

# %%
auth = urllib.parse.quote_plus("DRIVER={SQL Server};"
"SERVER=165.136.18.251;"
"DATABASE=Commercial;"
"UID=Com_admin;"
"PWD=star#com121")
engine = create_engine("mssql+pyodbc:///?odbc_connect={}".format(auth),fast_executemany=False)

# %%
import sqlalchemy

# %%
connection = engine.connect()
truncate_query = sqlalchemy.text("TRUNCATE TABLE TBL_Bronze")
connection.execution_options(autocommit=True).execute(truncate_query)

# %%
df1.to_sql('TBL_Bronze',con=engine,if_exists='_append',index=False)

# %%
pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    --- ------------------------------------ 1.3/16.1 MB 9.6 MB/s eta 0:00:02
#    --------- ------------------------------ 3.7/16.1 MB 9.5 MB/s eta 0:00:02
#    -------------- ------------------------- 5.8/16.1 MB 9.8 MB/s eta 0:00:02
#    ------------------ --------------------- 7.3/16.1 MB 9.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 9.2/16.1 MB 9.2 MB/s eta 0:00:01
#    --------------------------- ------------ 11.0/16.1 MB 9.1 MB/s eta 0:00:01
#    ------------------------------- -------- 12.6/16.1 MB 8.8 MB/s eta 0:00:01
#    ------------------------------------- -- 14.9/16.1 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------  16.0/16.1 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  16.0/16.1 MB 8.7 MB/s eta 0:00:01
# ...

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="SQL Server 15.0.2000.5",
  user="com_admin",
  password="star#com121",
  database="165.136.18.251"
)

mycursor = mydb.cursor()

sql = "Truncate TABLE TBL_Bronze"

mycursor.execute(sql)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\180100\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\connection_cext.py:335, in CMySQLConnection._open_connection(self)
#     334 try:
# --> 335     self._cmysql.connect(**cnx_kwargs)
#     336     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Unknown MySQL server host 'SQL Server 15.0.2000.5' (11001)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[8], line 3
#       1 import mysql.connector
# ----> 3 mydb = mysql.connector.connect(
#       4   host="SQL Server 15.0.2000.5",
#       5   user="com_admin",
#       6   password="star#com121",
#       7   database="165.136.18.251"
#       8 )
#      10 mycursor = mydb.cursor()
# ...

# %%
def sql_cnt():
    SERVER='165.136.18.251'
    DATABASE='Commercial'
    USERNAME='Com_admin'
    PASSWORD='star#com121'
    connectionString = f'DRIVER={{ODBC Driver 17 for SQL SERVER}};SERVER={SERVER};DATABASE={DATABASE};UID={USERNAME};PWD={PASSWORD}'
    cnxn = pyodbc.connect(connectionString)
    print("Driver connected")
    cursor = cnxn.cursor()
    return cursor,cnxn

# %%
mycursor = mydb.cursor()

sql = "Truncate TABLE TBL_Bronze"

mycursor.execute(sql)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 mycursor = mydb.cursor()
#       3 sql = "Truncate TABLE TBL_Bronze"
#       5 mycursor.execute(sql)
#
# NameError: name 'mydb' is not defined
