# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel(r'C:\Users\180100\OneDrive - NTT DATA North America\SAP\Output\call\DEC 03 test.xlsx')

# %%
df
# Out:
#        Employee Portal Id    Employee name  Work Date  Grade        Country  \
# 0                   13643     Puneet Kumar 2024-11-25     12          India
# 1                   13643     Puneet Kumar 2024-11-25     12          India
# 2                   13643     Puneet Kumar 2024-11-25     12          India
# 3                   13643     Puneet Kumar 2024-11-25     12          India
# 4                   13643     Puneet Kumar 2024-11-26     12          India
# ...                   ...              ...        ...    ...            ...
# 39592              338115   Tripti Khaneja 2024-11-27      5          India
# 39593              338115   Tripti Khaneja 2024-11-29      5          India
# 39594              338237  Muhammad Ismail 2024-11-25      3  United States
# 39595              338237  Muhammad Ismail 2024-11-26      3  United States
# 39596              338237  Muhammad Ismail 2024-11-27      3  United States
#
#                   WBS Element  HLM ID Att Type/Absence Type  Duplicate  \
# 0      R-0020058240-C00040-01   28875                   REG        0.0
# 1      R-0020105337-000010-01   28875                   REG        0.0
# 2      R-0040006953-000010-01   28875                   REG        0.0
# 3      R-0040006960-000010-01   28875                   REG        0.0
# 4      R-0020058240-C00040-01   28875                   REG        0.0
# ...                       ...     ...                   ...        ...
# 39592  R-0020091730-000010-02   78595                   REG        0.0
# 39593  R-0020091730-000010-02   78595                   REG        0.0
# 39594  R-0050001176-000080-01  240112                   REG        0.0
# 39595  R-0050001176-000080-01  240112                   REG        0.0
# 39596  R-0050001176-000080-01  240112                   REG        0.0
#
#        Total Hours
# 0              1.0
# 1              2.0
# 2              2.0
# 3              4.0
# 4              1.0
# ...            ...
# 39592          9.0
# 39593          9.0
# 39594          8.0
# 39595          8.0
# 39596          8.0
#
# [39597 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['Employee Portal Id', 'Employee name', 'Work Date', 'Grade', 'Country',
#        'WBS Element', 'HLM ID', 'Att Type/Absence Type', 'Duplicate',
#        'Total Hours'],
#       dtype='object')

# %%
#df = df[df['Att Type/Absence Type'].isin(["Bereavement","Casual Leave","Maternity Leave","Other Leaves","Parental Leave","Paternity Leave","Personal unpaid <=5","Privilege Leave","REG","Sick Leave","Sick Leave BPO","Sick Leave Temp","TRNG","Vacation","Sick Leave (US Temp)","Sick","Maternity Leave - pa","Parental Leave - pai","Mis-carriage Leave -"])]

# %%
#df['Att Type/Absence Type'] = df['Att Type/Absence Type'].replace(["Bereavement","Casual Leave","Maternity Leave","Other Leaves","Parental Leave","Paternity Leave","Personal unpaid <=5","Privilege Leave","Sick Leave","Sick Leave BPO","Sick Leave Temp","TRNG","Vacation","Sick Leave (US Temp)","Sick","Maternity Leave - pa","Parental Leave - pai","Mis-carriage Leave -"],["Other leaves","Other leaves","Other leaves","Other leaves","Other leaves","Other leaves","Other leaves","Other leaves","Other leaves","Other leaves","Other leaves","Other leaves","Other leaves","Other leaves","Other leaves","Other leaves","Other leaves","Other leaves"])

# %%
df['Att Type/Absence Type'].value_counts()
# Out:
# Att Type/Absence Type
# REG             38700
# Other leaves      897
# Name: count, dtype: int64

# %%
#dff = pd.DataFrame({"Total Hours": df.groupby(['Work Date','Geo','Employee Portal Id','Employee name','HLM ID','Att Type/Absence Type','Hours'])['Hours'].sum()}).reset_index()

# %%
#dff

# %%
#dff[dff['Employee Portal Id'] == 312553]

# %%
#dff['Duplicate']=dff['Total Hours']-dff['Hours']

# %%
#dff[dff['Employee Portal Id'] == 312553]

# %%
final = df.groupby(['Employee Portal Id','Employee name','Work Date','Grade','Country','HLM ID','Att Type/Absence Type']).agg({'Duplicate':'sum','Total Hours':'sum'}).reset_index()

# %%
final[final['Employee Portal Id'] == 312553]
# Out:
# Empty DataFrame
# Columns: [Employee Portal Id, Employee name, Work Date, Grade, Country, HLM ID, Att Type/Absence Type, Duplicate, Total Hours]
# Index: []

# %%
final[final['Employee Portal Id'] == 120145]
# Out:
#       Employee Portal Id   Employee name  Work Date  Grade        Country  \
# 1531              120145  Adam Lubojasky 2024-11-25      6  United States
#
#       HLM ID Att Type/Absence Type  Duplicate  Total Hours
# 1531  113210                   REG        0.0         13.0

# %%
final
# Out:
#        Employee Portal Id    Employee name  Work Date  Grade        Country  \
# 0                   13643     Puneet Kumar 2024-11-25     12          India
# 1                   13643     Puneet Kumar 2024-11-26     12          India
# 2                   13643     Puneet Kumar 2024-11-27     12          India
# 3                   13643     Puneet Kumar 2024-11-28     12          India
# 4                   13643     Puneet Kumar 2024-11-29     12          India
# ...                   ...              ...        ...    ...            ...
# 34702              338115   Tripti Khaneja 2024-11-27      5          India
# 34703              338115   Tripti Khaneja 2024-11-29      5          India
# 34704              338237  Muhammad Ismail 2024-11-25      3  United States
# 34705              338237  Muhammad Ismail 2024-11-26      3  United States
# 34706              338237  Muhammad Ismail 2024-11-27      3  United States
#
#        HLM ID Att Type/Absence Type  Duplicate  Total Hours
# 0       28875                   REG        0.0          9.0
# 1       28875                   REG        0.0          9.0
# 2       28875                   REG        0.0          9.0
# 3       28875                   REG        0.0          9.0
# 4       28875                   REG        0.0          9.0
# ...       ...                   ...        ...          ...
# 34702   78595                   REG        0.0          9.0
# 34703   78595                   REG        0.0          9.0
# 34704  240112                   REG        0.0          8.0
# 34705  240112                   REG        0.0          8.0
# 34706  240112                   REG        0.0          8.0
#
# [34707 rows x 9 columns]

# %%
WBS=final.to_excel(r'C:\Users\180100\OneDrive - NTT DATA North America\SAP\Output\call\Dec 03 duplicate.xlsx', index=False)
WBS
